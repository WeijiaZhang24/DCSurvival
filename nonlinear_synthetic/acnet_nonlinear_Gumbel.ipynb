# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

seed = 142857
rng = np.random.default_rng(seed)
from statsmodels.distributions.copula.api import (
    CopulaDistribution, GumbelCopula, FrankCopula, ClaytonCopula)

torch.backends.cudnn.allow_tf32 = False
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")
print(device)

torch.set_default_tensor_type(torch.DoubleTensor)

# Generate synthetic data (time-to-event and censoring indicator)
# np.random.seed(285714)
v_e=4; rho_e=17; v_c=3; rho_c=16

# for non-linear dim=1
size = 20000
dim = 1

# generate X from 10 dimensional uniform distribution from 0 to 1
X = np.random.uniform(0, 1, (size, dim))

# multiply beta_e with X to get event risk
event_risk = 2* np.sin(X*np.pi).squeeze() 
# multiple beta_c with X to get censoring risk
censoring_risk = 2* np.sin(X*np.pi+0.5).squeeze()

copula = GumbelCopula(theta=10)
sample = copula.rvs(size)
u = sample[:, 0]
v = sample[:, 1]
plt.scatter(u,v)


# Generate according to Algorithm 2 in "Copula-based Deep Survival Models for Dependent Censoring"
def inverse_transform(value, risk, shape, scale):
    return (-np.log(value)/np.exp(risk))**(1/shape)*scale       
    # return (-np.log(1-value)/np.exp(risk))**(1/shape)*scale


event_time = inverse_transform(u, event_risk, v_e, rho_e)
censoring_time = inverse_transform(v, censoring_risk, v_c, rho_c)

fig = plt.figure()
plt.scatter(event_time, censoring_time)

# check censoring rate 
print(np.sum(event_time<censoring_time)/len(event_time))

# create observed time 
observed_time = np.minimum(event_time, censoring_time)
event_indicator = (event_time<censoring_time).astype(int)
# Out:
# cuda
# 0.3082
# /home/weijia/anaconda3/lib/python3.10/site-packages/statsmodels/tools/rng_qrng.py:54: FutureWarning: Passing `None` as the seed currently return the NumPy singleton RandomState
# (np.random.mtrand._rand). After release 0.13 this will change to using the
# default generator provided by NumPy (np.random.default_rng()). If you need
# reproducible draws, you should pass a seeded np.random.Generator, e.g.,
#
# import numpy as np
# seed = 32839283923801
# rng = np.random.default_rng(seed)"
#
#   warnings.warn(_future_warn, FutureWarning)

# %%
from torch.utils.data import TensorDataset, DataLoader

times_tensor = torch.tensor(observed_time, dtype=torch.float64).to(device)
event_indicator_tensor = torch.tensor(event_indicator, dtype=torch.float64).to(device)
covariate_tensor = torch.tensor(X, dtype=torch.float64).to(device)
train_data = TensorDataset(covariate_tensor[0:10000], times_tensor[0:10000], event_indicator_tensor[0:10000])
val_data = TensorDataset(covariate_tensor[10000:], times_tensor[10000:], event_indicator_tensor[10000:])

batch_size = 10000

train_loader = DataLoader(
    train_data, batch_size= batch_size, shuffle=True)

val_loader = DataLoader(
    val_data, batch_size= batch_size, shuffle=True)

# %% [markdown]
# ### Define Likelihood with ACNET copula

# %%
from torch.autograd import Function, gradcheck
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pickle
import os,sys
sys.path.append(os.path.abspath('../'))
from main import sample

num_epochs = 500000

# %%
from dirac_phi import DiracPhi
from survival import SurvivalCopula_nonlinear
from survival import sample

import wandb

# start a new wandb run to track this script
run = wandb.init(
    # set the wandb project where this run will be logged
    project="ACNet Survival",
    # track hyperparameters and run metadata
    config={
    "dataset": "Gumbel Copula Weibull Non-linear Hazzards",
    "epochs": 50000,
    }
)


# Early stopping
best_val_loglikelihood = float('-inf')
epochs_no_improve = 0
early_stop_epochs = 5000

# Parameters for ACNet
depth = 2
widths = [10, 10]
lc_w_range = (0, 1.0)
shift_w_range = (0., 2.0)

phi = DiracPhi(depth, widths, lc_w_range, shift_w_range, device, tol = 1e-10).to(device)
model = SurvivalCopula_nonlinear(phi, device = device, num_features=1, tol=1e-10).to(device)
# optimizer = get_optim(optim_name, net, optim_args)

optimizer_event = optim.Adam([{"params": [model.scale_t], "lr": 0.01},
                            {"params": [model.shape_t], "lr": 0.01},
                            {"params": model.net_t.parameters(), "lr": 0.01},
                          ])
optimizer_censoring = optim.Adam([{"params": [model.scale_c], "lr": 0.01},
                            {"params": [model.shape_c], "lr": 0.01},
                            {"params": model.net_c.parameters(), "lr": 0.01},
                          ])
optimizer_copula = optim.Adam([
                            {"params": model.phi.parameters(), "lr": 0.01},
                          ])

train_loss_per_epoch = []
print("Start training!")
for epoch in range(num_epochs):
    loss_per_minibatch = []
    for i, (x , t, c) in enumerate(train_loader, 0):
        optimizer_copula.zero_grad()
        optimizer_event.zero_grad()
        optimizer_censoring.zero_grad()

        p = model(x, t, c, max_iter = 10000)
        logloss = -p
        logloss.backward() 
        scalar_loss = (logloss/p.numel()).detach().cpu().numpy().item()

        optimizer_censoring.step()
        optimizer_event.step()
        optimizer_copula.step()
        
        loss_per_minibatch.append(scalar_loss)
    train_loss_per_epoch.append(np.mean(loss_per_minibatch))
    if epoch % 100 == 0:
        print('Training loss at epoch %s: %.5f' %
                (epoch, train_loss_per_epoch[-1]))
        print(f"Shape Event: {model.shape_t.item(): .3f},\
            Shape Censoring: {model.shape_c.item(): .3f},\
            Scale Event: {model.scale_t.item(): .3f}, Scale Censoring: {model.scale_c.item(): .3f}")
    
        val_loglikelihoods = []
        for i, (x_val, t_val, c_val) in enumerate(val_loader, 0):
            p_val = model(x_val, t_val, c_val, max_iter = 10000)
            val_loglikelihood = p_val

        print('Validation log-likelihood at epoch %s: %s' % (epoch, val_loglikelihood.cpu().detach().numpy().item()))
    
        # Check if validation loglikelihood has improved
        if val_loglikelihood > best_val_loglikelihood:
            best_val_loglikelihood = val_loglikelihood
            epochs_no_improve = 0
            torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'loss': best_val_loglikelihood,
            }, './gumbel_checkpoint.pth')
        else:
            epochs_no_improve += 100

        # Early stopping condition
        if epochs_no_improve == early_stop_epochs:
            print('Early stopping triggered at epoch: %s' % epoch)
            break
    # Plot Samples from the learned copula
    if epoch % 1000 == 0:
        print('Scatter sampling')
        samples = sample(model, 2, 10000, device =  device)
        plt.scatter(samples[:, 0].cpu(), samples[:, 1].cpu())
        plt.savefig('./sample_figs/Gumbel/epoch%s.png' %
                    (epoch))
        plt.clf()
    
    wandb.log({"log_likelihood": p, 
                "event_shape": model.shape_t.item(), "censoring_shape": model.shape_c.item(), \
                "event_scale": model.scale_t.item(), "censoring_scale": model.scale_c.item()})


# Load the best model and plot samples
checkpoint = torch.load('./gumbel_checkpoint.pth')
model.load_state_dict(checkpoint['model_state_dict'])
samples = sample(model, 2, 10000, device =  device)
plt.scatter(samples[:, 0].cpu(), samples[:, 1].cpu())
plt.savefig('./sample_figs/Gumbel/best_epoch.png')
plt.clf()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: weijia-zhang (causal-learning). Use `wandb login --relogin` to force relogin
# wandb version 0.15.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.2
# Run data is saved locally in <code>/home/weijia/code/SurvivalACNet/nonlinear_synthetic/wandb/run-20230722_150154-bfk1ucic</code>
# Syncing run <strong><a href='https://wandb.ai/causal-learning/ACNet%20Survival/runs/bfk1ucic' target="_blank">fallen-shadow-61</a></strong> to <a href='https://wandb.ai/causal-learning/ACNet%20Survival' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/causal-learning/ACNet%20Survival' target="_blank">https://wandb.ai/causal-learning/ACNet%20Survival</a>
#  View run at <a href='https://wandb.ai/causal-learning/ACNet%20Survival/runs/bfk1ucic' target="_blank">https://wandb.ai/causal-learning/ACNet%20Survival/runs/bfk1ucic</a>
# Start training!
# Training loss at epoch 0: 134932.93621
# Shape Event:  0.990,            Shape Censoring:  0.990,            Scale Event:  1.010, Scale Censoring:  1.010
# Validation log-likelihood at epoch 0: -117130.8779802839
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 100: 34548.55625
# Shape Event:  0.954,            Shape Censoring:  1.058,            Scale Event:  1.143, Scale Censoring:  1.113
# Validation log-likelihood at epoch 100: -34569.05736095243
# Training loss at epoch 200: 32916.19749
# Shape Event:  1.103,            Shape Censoring:  1.309,            Scale Event:  1.143, Scale Censoring:  1.115
# Validation log-likelihood at epoch 200: -32932.40597025318
# Training loss at epoch 300: 31707.82695
# Shape Event:  1.272,            Shape Censoring:  1.545,            Scale Event:  1.143, Scale Censoring:  1.117
# Validation log-likelihood at epoch 300: -31718.81535460466
# Training loss at epoch 400: 30822.37674
# Shape Event:  1.446,            Shape Censoring:  1.754,            Scale Event:  1.143, Scale Censoring:  1.118
# Validation log-likelihood at epoch 400: -30826.28776205553
# Training loss at epoch 500: 30162.67139
# Shape Event:  1.622,            Shape Censoring:  1.935,            Scale Event:  1.143, Scale Censoring:  1.120
# Validation log-likelihood at epoch 500: -30158.98921605533
# Training loss at epoch 600: 29661.91852
# Shape Event:  1.795,            Shape Censoring:  2.089,            Scale Event:  1.143, Scale Censoring:  1.122
# Validation log-likelihood at epoch 600: -29654.031877120513
# Training loss at epoch 700: 29271.07815
# Shape Event:  1.966,            Shape Censoring:  2.219,            Scale Event:  1.143, Scale Censoring:  1.123
# Validation log-likelihood at epoch 700: -29254.370777027958
# Training loss at epoch 800: 28963.66163
# Shape Event:  2.133,            Shape Censoring:  2.327,            Scale Event:  1.143, Scale Censoring:  1.124
# Validation log-likelihood at epoch 800: -28941.657717977872
# Training loss at epoch 900: 28715.84182
# Shape Event:  2.296,            Shape Censoring:  2.415,            Scale Event:  1.143, Scale Censoring:  1.126
# Validation log-likelihood at epoch 900: -28688.286299457955
# Training loss at epoch 1000: 28513.66818
# Shape Event:  2.455,            Shape Censoring:  2.487,            Scale Event:  1.144, Scale Censoring:  1.127
# Validation log-likelihood at epoch 1000: -28481.301619465663
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 1100: 28344.57433
# Shape Event:  2.610,            Shape Censoring:  2.544,            Scale Event:  1.144, Scale Censoring:  1.128
# Validation log-likelihood at epoch 1100: -28305.179101348403
# Training loss at epoch 1200: 28201.03462
# Shape Event:  2.760,            Shape Censoring:  2.590,            Scale Event:  1.144, Scale Censoring:  1.130
# Validation log-likelihood at epoch 1200: -28153.114267068235
# Training loss at epoch 1300: 28079.78286
# Shape Event:  2.905,            Shape Censoring:  2.624,            Scale Event:  1.145, Scale Censoring:  1.131
# Validation log-likelihood at epoch 1300: -28026.86258044563
# Training loss at epoch 1400: 28001.68255
# Shape Event:  3.046,            Shape Censoring:  2.651,            Scale Event:  1.145, Scale Censoring:  1.132
# Validation log-likelihood at epoch 1400: -27975.866417172372
# Training loss at epoch 1500: 27883.99851
# Shape Event:  3.182,            Shape Censoring:  2.670,            Scale Event:  1.146, Scale Censoring:  1.134
# Validation log-likelihood at epoch 1500: -27821.186686124678
# Training loss at epoch 1600: 27806.44050
# Shape Event:  3.314,            Shape Censoring:  2.684,            Scale Event:  1.146, Scale Censoring:  1.134
# Validation log-likelihood at epoch 1600: -27737.26035687141
# Training loss at epoch 1700: 27737.09243
# Shape Event:  3.440,            Shape Censoring:  2.694,            Scale Event:  1.148, Scale Censoring:  1.135
# Validation log-likelihood at epoch 1700: -27664.729078087614
# Training loss at epoch 1800: 27677.66086
# Shape Event:  3.562,            Shape Censoring:  2.701,            Scale Event:  1.148, Scale Censoring:  1.136
# Validation log-likelihood at epoch 1800: -27601.106889358554
# Training loss at epoch 1900: 27627.00816
# Shape Event:  3.679,            Shape Censoring:  2.705,            Scale Event:  1.149, Scale Censoring:  1.137
# Validation log-likelihood at epoch 1900: -27546.09979412819
# Training loss at epoch 2000: 27589.49569
# Shape Event:  3.791,            Shape Censoring:  2.708,            Scale Event:  1.151, Scale Censoring:  1.138
# Validation log-likelihood at epoch 2000: -27511.299999286188
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 2100: 27550.29872
# Shape Event:  3.898,            Shape Censoring:  2.710,            Scale Event:  1.153, Scale Censoring:  1.139
# Validation log-likelihood at epoch 2100: -27458.378174152465
# Training loss at epoch 2200: 27511.38351
# Shape Event:  4.000,            Shape Censoring:  2.711,            Scale Event:  1.155, Scale Censoring:  1.141
# Validation log-likelihood at epoch 2200: -27421.58394712297
# Training loss at epoch 2300: 27482.86485
# Shape Event:  4.096,            Shape Censoring:  2.712,            Scale Event:  1.157, Scale Censoring:  1.142
# Validation log-likelihood at epoch 2300: -27388.77750359757
# Training loss at epoch 2400: 27459.00417
# Shape Event:  4.188,            Shape Censoring:  2.713,            Scale Event:  1.159, Scale Censoring:  1.142
# Validation log-likelihood at epoch 2400: -27362.143779427322
# Training loss at epoch 2500: 27438.25856
# Shape Event:  4.275,            Shape Censoring:  2.713,            Scale Event:  1.161, Scale Censoring:  1.144
# Validation log-likelihood at epoch 2500: -27336.43725389044
# Training loss at epoch 2600: 27426.78704
# Shape Event:  4.325,            Shape Censoring:  2.713,            Scale Event:  1.238, Scale Censoring:  1.146
# Validation log-likelihood at epoch 2600: -27328.519350821367
# Training loss at epoch 2700: 27411.76455
# Shape Event:  4.400,            Shape Censoring:  2.713,            Scale Event:  1.238, Scale Censoring:  1.147
# Validation log-likelihood at epoch 2700: -27308.422948923595
# Training loss at epoch 2800: 27399.98815
# Shape Event:  4.471,            Shape Censoring:  2.713,            Scale Event:  1.238, Scale Censoring:  1.148
# Validation log-likelihood at epoch 2800: -27292.964447799903
# Training loss at epoch 2900: 27389.33913
# Shape Event:  4.537,            Shape Censoring:  2.714,            Scale Event:  1.238, Scale Censoring:  1.150
# Validation log-likelihood at epoch 2900: -27284.087445037185
# Training loss at epoch 3000: 27367.89248
# Shape Event:  4.601,            Shape Censoring:  2.715,            Scale Event:  1.238, Scale Censoring:  1.152
# Validation log-likelihood at epoch 3000: -27254.99190576406
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 3100: 27170.76814
# Shape Event:  4.647,            Shape Censoring:  2.714,            Scale Event:  1.236, Scale Censoring:  1.164
# Validation log-likelihood at epoch 3100: -27037.37033885467
# Training loss at epoch 3200: 27139.16294
# Shape Event:  4.662,            Shape Censoring:  2.716,            Scale Event:  1.237, Scale Censoring:  1.179
# Validation log-likelihood at epoch 3200: -27051.695160699812
# Training loss at epoch 3300: 27036.14031
# Shape Event:  4.662,            Shape Censoring:  2.718,            Scale Event:  1.256, Scale Censoring:  1.205
# Validation log-likelihood at epoch 3300: -26895.860444672406
# Training loss at epoch 3400: 26994.38399
# Shape Event:  4.654,            Shape Censoring:  2.740,            Scale Event:  1.254, Scale Censoring:  1.207
# Validation log-likelihood at epoch 3400: -26864.57808188
# Training loss at epoch 3500: 26974.46373
# Shape Event:  4.644,            Shape Censoring:  2.738,            Scale Event:  1.260, Scale Censoring:  1.216
# Validation log-likelihood at epoch 3500: -26857.179690322766
# Training loss at epoch 3600: 26976.86728
# Shape Event:  4.629,            Shape Censoring:  2.743,            Scale Event:  1.262, Scale Censoring:  1.221
# Validation log-likelihood at epoch 3600: -26874.20133112135
# Training loss at epoch 3700: 26949.90372
# Shape Event:  4.611,            Shape Censoring:  2.751,            Scale Event:  1.266, Scale Censoring:  1.226
# Validation log-likelihood at epoch 3700: -26828.549158580572
# Training loss at epoch 3800: 26966.93371
# Shape Event:  4.591,            Shape Censoring:  2.759,            Scale Event:  1.271, Scale Censoring:  1.233
# Validation log-likelihood at epoch 3800: -26850.569391438323
# Training loss at epoch 3900: 26968.40349
# Shape Event:  4.572,            Shape Censoring:  2.767,            Scale Event:  1.276, Scale Censoring:  1.239
# Validation log-likelihood at epoch 3900: -26824.369065413637
# Training loss at epoch 4000: 26904.04503
# Shape Event:  4.554,            Shape Censoring:  2.773,            Scale Event:  1.280, Scale Censoring:  1.245
# Validation log-likelihood at epoch 4000: -26781.740783107314
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 4100: 26913.14023
# Shape Event:  4.538,            Shape Censoring:  2.778,            Scale Event:  1.284, Scale Censoring:  1.251
# Validation log-likelihood at epoch 4100: -26813.06571487467
# Training loss at epoch 4200: 26918.79843
# Shape Event:  4.522,            Shape Censoring:  2.781,            Scale Event:  1.289, Scale Censoring:  1.256
# Validation log-likelihood at epoch 4200: -26767.2394190543
# Training loss at epoch 4300: 26919.78112
# Shape Event:  4.509,            Shape Censoring:  2.784,            Scale Event:  1.292, Scale Censoring:  1.262
# Validation log-likelihood at epoch 4300: -26818.648482725002
# Training loss at epoch 4400: 26904.31916
# Shape Event:  4.496,            Shape Censoring:  2.787,            Scale Event:  1.297, Scale Censoring:  1.266
# Validation log-likelihood at epoch 4400: -26772.16870746527
# Training loss at epoch 4500: 26896.64691
# Shape Event:  4.483,            Shape Censoring:  2.792,            Scale Event:  1.300, Scale Censoring:  1.271
# Validation log-likelihood at epoch 4500: -26769.288452735917
# Training loss at epoch 4600: 26927.19374
# Shape Event:  4.472,            Shape Censoring:  2.794,            Scale Event:  1.304, Scale Censoring:  1.275
# Validation log-likelihood at epoch 4600: -26767.09444107312
# Training loss at epoch 4700: 26881.21224
# Shape Event:  4.465,            Shape Censoring:  2.795,            Scale Event:  1.307, Scale Censoring:  1.279
# Validation log-likelihood at epoch 4700: -26760.03955313305
# Training loss at epoch 4800: 26885.74220
# Shape Event:  4.460,            Shape Censoring:  2.796,            Scale Event:  1.312, Scale Censoring:  1.284
# Validation log-likelihood at epoch 4800: -26755.145017110815
# Training loss at epoch 4900: 26900.96718
# Shape Event:  4.454,            Shape Censoring:  2.798,            Scale Event:  1.315, Scale Censoring:  1.288
# Validation log-likelihood at epoch 4900: -26758.41077115637
# Training loss at epoch 5000: 26886.24666
# Shape Event:  4.450,            Shape Censoring:  2.799,            Scale Event:  1.319, Scale Censoring:  1.293
# Validation log-likelihood at epoch 5000: -26755.95595942941
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 5100: 26878.57071
# Shape Event:  4.446,            Shape Censoring:  2.802,            Scale Event:  1.323, Scale Censoring:  1.297
# Validation log-likelihood at epoch 5100: -26774.4343167963
# Training loss at epoch 5200: 26870.96376
# Shape Event:  4.445,            Shape Censoring:  2.797,            Scale Event:  1.329, Scale Censoring:  1.304
# Validation log-likelihood at epoch 5200: -26740.62374921023
# Training loss at epoch 5300: 26862.61904
# Shape Event:  4.436,            Shape Censoring:  2.803,            Scale Event:  1.328, Scale Censoring:  1.304
# Validation log-likelihood at epoch 5300: -26738.14932993883
# Training loss at epoch 5400: 26847.56642
# Shape Event:  4.431,            Shape Censoring:  2.794,            Scale Event:  1.332, Scale Censoring:  1.309
# Validation log-likelihood at epoch 5400: -26725.206349465516
# Training loss at epoch 5500: 26846.45473
# Shape Event:  4.423,            Shape Censoring:  2.793,            Scale Event:  1.333, Scale Censoring:  1.310
# Validation log-likelihood at epoch 5500: -26718.99802734281
# Training loss at epoch 5600: 26858.33442
# Shape Event:  4.416,            Shape Censoring:  2.794,            Scale Event:  1.337, Scale Censoring:  1.315
# Validation log-likelihood at epoch 5600: -26716.566510465746
# Training loss at epoch 5700: 26834.95070
# Shape Event:  4.409,            Shape Censoring:  2.797,            Scale Event:  1.341, Scale Censoring:  1.320
# Validation log-likelihood at epoch 5700: -26718.20201949338
# Training loss at epoch 5800: 26839.75874
# Shape Event:  4.402,            Shape Censoring:  2.800,            Scale Event:  1.345, Scale Censoring:  1.325
# Validation log-likelihood at epoch 5800: -26732.005193126537
# Training loss at epoch 5900: 26851.80875
# Shape Event:  4.395,            Shape Censoring:  2.802,            Scale Event:  1.349, Scale Censoring:  1.330
# Validation log-likelihood at epoch 5900: -26726.634292558898
# Training loss at epoch 6000: 26829.59321
# Shape Event:  4.387,            Shape Censoring:  2.805,            Scale Event:  1.353, Scale Censoring:  1.334
# Validation log-likelihood at epoch 6000: -26708.303263140475
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 6100: 26850.03420
# Shape Event:  4.381,            Shape Censoring:  2.808,            Scale Event:  1.356, Scale Censoring:  1.339
# Validation log-likelihood at epoch 6100: -26760.8026147618
# Training loss at epoch 6200: 26839.32811
# Shape Event:  4.375,            Shape Censoring:  2.809,            Scale Event:  1.360, Scale Censoring:  1.343
# Validation log-likelihood at epoch 6200: -26742.047126886697
# Training loss at epoch 6300: 26828.90335
# Shape Event:  4.373,            Shape Censoring:  2.802,            Scale Event:  1.366, Scale Censoring:  1.350
# Validation log-likelihood at epoch 6300: -26701.175724133675
# Training loss at epoch 6400: 26817.34772
# Shape Event:  4.359,            Shape Censoring:  2.815,            Scale Event:  1.365, Scale Censoring:  1.351
# Validation log-likelihood at epoch 6400: -26700.0754094211
# Training loss at epoch 6500: 26817.94780
# Shape Event:  4.349,            Shape Censoring:  2.815,            Scale Event:  1.368, Scale Censoring:  1.355
# Validation log-likelihood at epoch 6500: -26715.740480195782
# Training loss at epoch 6600: 26832.91170
# Shape Event:  4.339,            Shape Censoring:  2.818,            Scale Event:  1.370, Scale Censoring:  1.358
# Validation log-likelihood at epoch 6600: -26708.517852817986
# Training loss at epoch 6700: 26833.98343
# Shape Event:  4.331,            Shape Censoring:  2.820,            Scale Event:  1.373, Scale Censoring:  1.363
# Validation log-likelihood at epoch 6700: -26709.29815436255
# Training loss at epoch 6800: 26841.29726
# Shape Event:  4.324,            Shape Censoring:  2.822,            Scale Event:  1.376, Scale Censoring:  1.367
# Validation log-likelihood at epoch 6800: -26754.609189486506
# Training loss at epoch 6900: 26851.99923
# Shape Event:  4.317,            Shape Censoring:  2.822,            Scale Event:  1.381, Scale Censoring:  1.372
# Validation log-likelihood at epoch 6900: -26693.54707784381
# Training loss at epoch 7000: 26842.81509
# Shape Event:  4.311,            Shape Censoring:  2.825,            Scale Event:  1.383, Scale Censoring:  1.376
# Validation log-likelihood at epoch 7000: -26761.030256645863
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 7100: 26838.87573
# Shape Event:  4.306,            Shape Censoring:  2.827,            Scale Event:  1.386, Scale Censoring:  1.380
# Validation log-likelihood at epoch 7100: -26752.842651914165
# Training loss at epoch 7200: 26817.86470
# Shape Event:  4.300,            Shape Censoring:  2.828,            Scale Event:  1.389, Scale Censoring:  1.384
# Validation log-likelihood at epoch 7200: -26720.855858886014
# Training loss at epoch 7300: 26812.29968
# Shape Event:  4.300,            Shape Censoring:  2.816,            Scale Event:  1.397, Scale Censoring:  1.391
# Validation log-likelihood at epoch 7300: -26701.119827567352
# Training loss at epoch 7400: 26794.99255
# Shape Event:  4.300,            Shape Censoring:  2.816,            Scale Event:  1.397, Scale Censoring:  1.391
# Validation log-likelihood at epoch 7400: -26670.567411632248
# Training loss at epoch 7500: 26790.05779
# Shape Event:  4.293,            Shape Censoring:  2.824,            Scale Event:  1.397, Scale Censoring:  1.392
# Validation log-likelihood at epoch 7500: -26667.58153145588
# Training loss at epoch 7600: 26798.40433
# Shape Event:  4.288,            Shape Censoring:  2.823,            Scale Event:  1.401, Scale Censoring:  1.396
# Validation log-likelihood at epoch 7600: -26667.513042665283
# Training loss at epoch 7700: 26790.79532
# Shape Event:  4.281,            Shape Censoring:  2.827,            Scale Event:  1.404, Scale Censoring:  1.399
# Validation log-likelihood at epoch 7700: -26669.938016880275
# Training loss at epoch 7800: 26812.63363
# Shape Event:  4.276,            Shape Censoring:  2.829,            Scale Event:  1.408, Scale Censoring:  1.403
# Validation log-likelihood at epoch 7800: -26693.51390532308
# Training loss at epoch 7900: 26842.27386
# Shape Event:  4.271,            Shape Censoring:  2.830,            Scale Event:  1.411, Scale Censoring:  1.408
# Validation log-likelihood at epoch 7900: -26689.239254150692
# Training loss at epoch 8000: 26839.19194
# Shape Event:  4.265,            Shape Censoring:  2.833,            Scale Event:  1.414, Scale Censoring:  1.412
# Validation log-likelihood at epoch 8000: -26747.96925317432
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 8100: 26781.55659
# Shape Event:  4.259,            Shape Censoring:  2.835,            Scale Event:  1.419, Scale Censoring:  1.416
# Validation log-likelihood at epoch 8100: -26660.10689370107
# Training loss at epoch 8200: 26786.85357
# Shape Event:  4.254,            Shape Censoring:  2.837,            Scale Event:  1.422, Scale Censoring:  1.420
# Validation log-likelihood at epoch 8200: -26659.23791240213
# Training loss at epoch 8300: 26778.62357
# Shape Event:  4.249,            Shape Censoring:  2.838,            Scale Event:  1.426, Scale Censoring:  1.424
# Validation log-likelihood at epoch 8300: -26659.921925068273
# Training loss at epoch 8400: 26846.03681
# Shape Event:  4.243,            Shape Censoring:  2.840,            Scale Event:  1.430, Scale Censoring:  1.427
# Validation log-likelihood at epoch 8400: -26708.87796265942
# Training loss at epoch 8500: 26822.71656
# Shape Event:  4.240,            Shape Censoring:  2.840,            Scale Event:  1.432, Scale Censoring:  1.431
# Validation log-likelihood at epoch 8500: -26738.489756576622
# Training loss at epoch 8600: 26840.73277
# Shape Event:  4.235,            Shape Censoring:  2.842,            Scale Event:  1.437, Scale Censoring:  1.434
# Validation log-likelihood at epoch 8600: -26701.048852431544
# Training loss at epoch 8700: 26846.02823
# Shape Event:  4.232,            Shape Censoring:  2.842,            Scale Event:  1.439, Scale Censoring:  1.438
# Validation log-likelihood at epoch 8700: -26756.41263326237
# Training loss at epoch 8800: 26843.78048
# Shape Event:  4.228,            Shape Censoring:  2.844,            Scale Event:  1.443, Scale Censoring:  1.441
# Validation log-likelihood at epoch 8800: -26694.695336063
# Training loss at epoch 8900: 26782.80716
# Shape Event:  4.226,            Shape Censoring:  2.843,            Scale Event:  1.446, Scale Censoring:  1.444
# Validation log-likelihood at epoch 8900: -26669.010796373936
# Training loss at epoch 9000: 26786.36964
# Shape Event:  4.223,            Shape Censoring:  2.844,            Scale Event:  1.449, Scale Censoring:  1.447
# Validation log-likelihood at epoch 9000: -26660.704875717987
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 9100: 26773.75576
# Shape Event:  4.220,            Shape Censoring:  2.845,            Scale Event:  1.452, Scale Censoring:  1.450
# Validation log-likelihood at epoch 9100: -26659.648180369386
# Training loss at epoch 9200: 26777.67043
# Shape Event:  4.218,            Shape Censoring:  2.845,            Scale Event:  1.455, Scale Censoring:  1.453
# Validation log-likelihood at epoch 9200: -26660.976160872553
# Training loss at epoch 9300: 26790.95815
# Shape Event:  4.215,            Shape Censoring:  2.845,            Scale Event:  1.458, Scale Censoring:  1.456
# Validation log-likelihood at epoch 9300: -26673.412122217345
# Training loss at epoch 9400: 26817.78917
# Shape Event:  4.213,            Shape Censoring:  2.846,            Scale Event:  1.461, Scale Censoring:  1.459
# Validation log-likelihood at epoch 9400: -26674.35305545026
# Training loss at epoch 9500: 26788.79856
# Shape Event:  4.212,            Shape Censoring:  2.846,            Scale Event:  1.463, Scale Censoring:  1.462
# Validation log-likelihood at epoch 9500: -26698.12043410274
# Training loss at epoch 9600: 26797.78138
# Shape Event:  4.210,            Shape Censoring:  2.846,            Scale Event:  1.466, Scale Censoring:  1.465
# Validation log-likelihood at epoch 9600: -26682.057540394064
# Training loss at epoch 9700: 26779.21528
# Shape Event:  4.208,            Shape Censoring:  2.847,            Scale Event:  1.469, Scale Censoring:  1.468
# Validation log-likelihood at epoch 9700: -26668.323814896834
# Training loss at epoch 9800: 26784.49971
# Shape Event:  4.207,            Shape Censoring:  2.847,            Scale Event:  1.472, Scale Censoring:  1.471
# Validation log-likelihood at epoch 9800: -26669.861484834928
# Training loss at epoch 9900: 26788.98011
# Shape Event:  4.206,            Shape Censoring:  2.847,            Scale Event:  1.475, Scale Censoring:  1.473
# Validation log-likelihood at epoch 9900: -26675.043751038596
# Training loss at epoch 10000: 26780.06133
# Shape Event:  4.204,            Shape Censoring:  2.848,            Scale Event:  1.478, Scale Censoring:  1.476
# Validation log-likelihood at epoch 10000: -26666.73018973568
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 10100: 26772.21002
# Shape Event:  4.203,            Shape Censoring:  2.848,            Scale Event:  1.481, Scale Censoring:  1.479
# Validation log-likelihood at epoch 10100: -26659.923005610133
# Training loss at epoch 10200: 26772.96819
# Shape Event:  4.202,            Shape Censoring:  2.848,            Scale Event:  1.484, Scale Censoring:  1.482
# Validation log-likelihood at epoch 10200: -26661.942871393287
# Training loss at epoch 10300: 26780.45079
# Shape Event:  4.202,            Shape Censoring:  2.848,            Scale Event:  1.487, Scale Censoring:  1.485
# Validation log-likelihood at epoch 10300: -26669.89141618714
# Training loss at epoch 10400: 26772.23435
# Shape Event:  4.201,            Shape Censoring:  2.848,            Scale Event:  1.490, Scale Censoring:  1.487
# Validation log-likelihood at epoch 10400: -26661.47236826369
# Training loss at epoch 10500: 26774.64502
# Shape Event:  4.200,            Shape Censoring:  2.848,            Scale Event:  1.492, Scale Censoring:  1.490
# Validation log-likelihood at epoch 10500: -26663.842181875247
# Training loss at epoch 10600: 26797.33899
# Shape Event:  4.199,            Shape Censoring:  2.849,            Scale Event:  1.496, Scale Censoring:  1.492
# Validation log-likelihood at epoch 10600: -26681.241169850768
# Training loss at epoch 10700: 26813.98994
# Shape Event:  4.198,            Shape Censoring:  2.849,            Scale Event:  1.498, Scale Censoring:  1.495
# Validation log-likelihood at epoch 10700: -26694.84307268783
# Training loss at epoch 10800: 26810.47844
# Shape Event:  4.198,            Shape Censoring:  2.849,            Scale Event:  1.501, Scale Censoring:  1.497
# Validation log-likelihood at epoch 10800: -26690.142773384665
# Training loss at epoch 10900: 26844.31305
# Shape Event:  4.197,            Shape Censoring:  2.849,            Scale Event:  1.504, Scale Censoring:  1.500
# Validation log-likelihood at epoch 10900: -26699.743458416764
# Training loss at epoch 11000: 26844.63225
# Shape Event:  4.197,            Shape Censoring:  2.848,            Scale Event:  1.506, Scale Censoring:  1.503
# Validation log-likelihood at epoch 11000: -26736.84621539177
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 11100: 26773.78796
# Shape Event:  4.196,            Shape Censoring:  2.849,            Scale Event:  1.509, Scale Censoring:  1.505
# Validation log-likelihood at epoch 11100: -26661.51887692915
# Training loss at epoch 11200: 26771.65729
# Shape Event:  4.196,            Shape Censoring:  2.849,            Scale Event:  1.512, Scale Censoring:  1.508
# Validation log-likelihood at epoch 11200: -26660.41479935532
# Training loss at epoch 11300: 26823.63905
# Shape Event:  4.196,            Shape Censoring:  2.849,            Scale Event:  1.515, Scale Censoring:  1.511
# Validation log-likelihood at epoch 11300: -26701.439837152182
# Training loss at epoch 11400: 26794.15120
# Shape Event:  4.195,            Shape Censoring:  2.850,            Scale Event:  1.518, Scale Censoring:  1.513
# Validation log-likelihood at epoch 11400: -26678.69980305829
# Training loss at epoch 11500: 26771.34882
# Shape Event:  4.195,            Shape Censoring:  2.849,            Scale Event:  1.520, Scale Censoring:  1.516
# Validation log-likelihood at epoch 11500: -26664.5916586228
# Training loss at epoch 11600: 26830.12296
# Shape Event:  4.195,            Shape Censoring:  2.849,            Scale Event:  1.523, Scale Censoring:  1.518
# Validation log-likelihood at epoch 11600: -26732.4894815425
# Training loss at epoch 11700: 26802.64856
# Shape Event:  4.194,            Shape Censoring:  2.849,            Scale Event:  1.526, Scale Censoring:  1.521
# Validation log-likelihood at epoch 11700: -26720.050898948713
# Training loss at epoch 11800: 26817.20361
# Shape Event:  4.194,            Shape Censoring:  2.849,            Scale Event:  1.529, Scale Censoring:  1.523
# Validation log-likelihood at epoch 11800: -26710.884420993894
# Training loss at epoch 11900: 26771.60203
# Shape Event:  4.194,            Shape Censoring:  2.850,            Scale Event:  1.532, Scale Censoring:  1.526
# Validation log-likelihood at epoch 11900: -26661.8648070984
# Training loss at epoch 12000: 26770.50376
# Shape Event:  4.193,            Shape Censoring:  2.850,            Scale Event:  1.534, Scale Censoring:  1.528
# Validation log-likelihood at epoch 12000: -26662.757943181336
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 12100: 26788.43278
# Shape Event:  4.193,            Shape Censoring:  2.850,            Scale Event:  1.537, Scale Censoring:  1.531
# Validation log-likelihood at epoch 12100: -26702.128440631386
# Training loss at epoch 12200: 26787.16544
# Shape Event:  4.192,            Shape Censoring:  2.850,            Scale Event:  1.540, Scale Censoring:  1.532
# Validation log-likelihood at epoch 12200: -26674.81170272544
# Training loss at epoch 12300: 26776.24011
# Shape Event:  4.192,            Shape Censoring:  2.850,            Scale Event:  1.543, Scale Censoring:  1.535
# Validation log-likelihood at epoch 12300: -26663.70420178817
# Training loss at epoch 12400: 26777.72261
# Shape Event:  4.192,            Shape Censoring:  2.851,            Scale Event:  1.546, Scale Censoring:  1.537
# Validation log-likelihood at epoch 12400: -26664.387791255424
# Training loss at epoch 12500: 26774.36734
# Shape Event:  4.192,            Shape Censoring:  2.850,            Scale Event:  1.548, Scale Censoring:  1.540
# Validation log-likelihood at epoch 12500: -26664.927908202684
# Training loss at epoch 12600: 26773.60366
# Shape Event:  4.192,            Shape Censoring:  2.850,            Scale Event:  1.551, Scale Censoring:  1.542
# Validation log-likelihood at epoch 12600: -26662.101874755725
# Training loss at epoch 12700: 26773.66655
# Shape Event:  4.191,            Shape Censoring:  2.850,            Scale Event:  1.554, Scale Censoring:  1.545
# Validation log-likelihood at epoch 12700: -26663.239491324715
# Training loss at epoch 12800: 26771.74682
# Shape Event:  4.191,            Shape Censoring:  2.850,            Scale Event:  1.557, Scale Censoring:  1.547
# Validation log-likelihood at epoch 12800: -26671.75115773585
# Training loss at epoch 12900: 26785.97378
# Shape Event:  4.191,            Shape Censoring:  2.850,            Scale Event:  1.559, Scale Censoring:  1.550
# Validation log-likelihood at epoch 12900: -26676.52049886612
# Training loss at epoch 13000: 26846.01650
# Shape Event:  4.191,            Shape Censoring:  2.851,            Scale Event:  1.562, Scale Censoring:  1.552
# Validation log-likelihood at epoch 13000: -26741.278029938556
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 13100: 26795.92001
# Shape Event:  4.190,            Shape Censoring:  2.851,            Scale Event:  1.566, Scale Censoring:  1.554
# Validation log-likelihood at epoch 13100: -26668.002475618436
# Training loss at epoch 13200: 26770.39483
# Shape Event:  4.189,            Shape Censoring:  2.851,            Scale Event:  1.568, Scale Censoring:  1.557
# Validation log-likelihood at epoch 13200: -26661.00874501762
# Early stopping triggered at epoch: 13200
# Sampling from dim: 1

# %% [markdown]
# ### Plotting

# %%
# Scatter Plot
checkpoint = torch.load('gumbel_checkpoint.pth')
model.load_state_dict(checkpoint['model_state_dict'])
samples =  sample(model, 2, 3000, device =  device)
plt.scatter(samples[:, 0].cpu(), samples[:, 1].cpu(), s = 15)
plt.savefig('./sample_figs/Gumbel/Gumble_Learned_Sample.png')
plt.clf()

# plotting with known copula
known_copula = GumbelCopula(10, k_dim=2)
samples_known = known_copula.rvs(3000)
plt.scatter(samples_known[:, 0], samples_known[:, 1], s = 15)

plt.savefig('./sample_figs/Gumbel/Gumble_Known_Sample.png')
plt.clf()
# Out:
# Sampling from dim: 1
# /home/weijia/anaconda3/lib/python3.10/site-packages/statsmodels/tools/rng_qrng.py:54: FutureWarning: Passing `None` as the seed currently return the NumPy singleton RandomState
# (np.random.mtrand._rand). After release 0.13 this will change to using the
# default generator provided by NumPy (np.random.default_rng()). If you need
# reproducible draws, you should pass a seeded np.random.Generator, e.g.,
#
# import numpy as np
# seed = 32839283923801
# rng = np.random.default_rng(seed)"
#
#   warnings.warn(_future_warn, FutureWarning)

# %% [markdown]
# #### Joint Distribution (Cumulative Distribution Function) Spectral Plot

# %%
# learned model
n = 500
x1 = np.linspace(0.001, 1, n)
x2 = np.linspace(0.001, 1, n)
xv1, xv2 = np.meshgrid(x1, x2)
xv1_tensor = torch.tensor(xv1.flatten()).to(device)
xv2_tensor = torch.tensor(xv2.flatten()).to(device)
query = torch.stack((xv1_tensor, xv2_tensor)
                    ).double().t().requires_grad_(True)
cdf = model.cond_cdf(query, mode='cdf')
pdf = model.cond_cdf(query, mode='pdf')

heat_cdf = cdf.reshape(n,n).cpu().detach().numpy()
heat_pdf = pdf.reshape(n,n).cpu().detach().numpy()

# Create filled contour plot
plt.contourf(x1, x2, heat_cdf, 200, cmap='Spectral_r')
# Add a colorbar
# plt.colorbar(label='Cumulative Distribution Function')
# Show the plot
plt.savefig('./sample_figs/Gumbel/Gumbel_Learned_CDF.png', dpi=300)

plt.clf()
# Create filled contour plot
plt.contourf(x1, x2, np.log(heat_pdf), 200, cmap='Spectral_r')
# Add a colorbar
# plt.colorbar(label='Log Density Function')
# Show the plot
plt.savefig('./sample_figs/Gumbel/Gumbel_Learned_LogPDF.png', dpi=300)

# %%
# Known copula
from statsmodels.distributions.copula.api import (
    CopulaDistribution, GumbelCopula, FrankCopula, ClaytonCopula)

n = 1000
x1 = np.linspace(0.001, 1, n)
x2 = np.linspace(0.001, 1, n)
xv1, xv2 = np.meshgrid(x1, x2)
xv1_tensor = torch.tensor(xv1.flatten())
xv2_tensor = torch.tensor(xv2.flatten())
query = torch.stack((xv1_tensor, xv2_tensor)
                    ).t().numpy()
print(query.shape)

known_copula = GumbelCopula(10, k_dim=2)
heat_cdf = known_copula.cdf(u=query).reshape(n,n)
heat_pdf = known_copula.pdf(u=query).reshape(n,n)

# Create filled contour plot
plt.contourf(x1, x2, heat_cdf, 200, cmap='Spectral_r')
plt.tick_params(axis='both', direction='in', length=4, width=1)
# Add a colorbar
# plt.colorbar(label='Cumulative Distribution Function')
# Show the plot
# plt.show()
plt.savefig('./sample_figs/Gumbel/Gumbel_Known_CDF.png', dpi=300)

plt.clf()
# Create filled contour plot
plt.contourf(x1, x2, np.log(heat_pdf), 200, cmap='Spectral_r')
plt.tick_params(axis='both', direction='in', length=4, width=1)
# Add a colorbar
# plt.colorbar(label='Log Density Function')
# Show the plot
# plt.show()
plt.savefig('./sample_figs/Gumbel/Gumbel_Known_LogPDF.png', dpi=300)
# Out:
# (1000000, 2)
# /home/weijia/anaconda3/lib/python3.10/site-packages/statsmodels/distributions/copula/archimedean.py:374: RuntimeWarning: divide by zero encountered in power
#   c = sum_xy_theta ** (1.0 / th - 2)
# /home/weijia/anaconda3/lib/python3.10/site-packages/statsmodels/distributions/copula/archimedean.py:378: RuntimeWarning: invalid value encountered in multiply
#   return a * b * c * d * e
# /tmp/ipykernel_31810/1614271320.py:30: RuntimeWarning: divide by zero encountered in log
#   plt.contourf(x1, x2, np.log(heat_pdf), 200, cmap='Spectral_r')
