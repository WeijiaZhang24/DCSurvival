# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

seed = 142857
rng = np.random.default_rng(seed)
from statsmodels.distributions.copula.api import (
    CopulaDistribution, GumbelCopula, FrankCopula, ClaytonCopula)

torch.backends.cudnn.allow_tf32 = False
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")
print(device)

torch.set_default_tensor_type(torch.DoubleTensor)

# Generate synthetic data (time-to-event and censoring indicator)
np.random.seed(285714)
v_e=np.float128(4); rho_e=np.float128(14); v_c=np.float128(3); rho_c=np.float128(16)

size = 20000
dim = 10

# generate X from 10 dimensional uniform distribution from 0 to 1
X = np.random.uniform(0, 1, (size, dim))
# generate censoring risk coefficient beta from 10 dimensional uniforma distribution from 0 to 1
beta_c = np.random.uniform(0, 1, (dim, ))
# generate event risk coefficient beta_e from 10 dimensional uniforma distribution from 0 to 1
beta_e = np.random.uniform(0, 1, (dim,))
# multiply beta_e with X to get event risk
event_risk = np.matmul(X, beta_e).squeeze()
# multiple beta_c with X to get censoring risk
censoring_risk = np.matmul(X, beta_c).squeeze()


copula = GumbelCopula(theta=2)
sample = copula.rvs(size)
u = sample[:, 0].astype(np.float64)
v = sample[:, 1].astype(np.float64)
plt.scatter(u,v)


# Generate according to Algorithm 2 in "Copula-based Deep Survival Models for Dependent Censoring"
def inverse_transform(value, risk, shape, scale):
    # return (-np.log(1-value)/risk)**(1/shape)*scale 
    return np.power(-np.log(1-value)/risk, 1/shape)*scale
    # return (-np.log(1-value)/np.exp(risk))**(1/shape)*scale


event_time = inverse_transform(u, event_risk, v_e, rho_e)
censoring_time = inverse_transform(v, censoring_risk, v_c, rho_c)

fig = plt.figure()
plt.scatter(event_time, censoring_time)

# check censoring rate 
print(np.sum(event_time<censoring_time)/len(event_time))

# create observed time 
observed_time = np.minimum(event_time, censoring_time)
event_indicator = (event_time<censoring_time).astype(int)
# Out:
# cuda
# 0.0
# /tmp/ipykernel_52800/166178076.py:51: RuntimeWarning: invalid value encountered in log
#   return np.power(-np.log(-value)/risk, 1/shape)*scale

# %%
from statsmodels.distributions.copula.api import ClaytonCopula,GumbelCopula
cp = GumbelCopula()
cp.fit_corr_param(np.array([event_time,censoring_time]).T)
# cp.fit_corr_param(np.array([u,v]).T)
# Out:
# 2.0103768376441615

# %%
from torch.utils.data import TensorDataset, DataLoader

times_tensor = torch.tensor(observed_time, dtype=torch.float64).to(device)
event_indicator_tensor = torch.tensor(event_indicator, dtype=torch.float64).to(device)
covariate_tensor = torch.tensor(X, dtype=torch.float64).to(device)
train_data = TensorDataset(covariate_tensor[0:10000], times_tensor[0:10000], event_indicator_tensor[0:10000])
val_data = TensorDataset(covariate_tensor[10000:], times_tensor[10000:], event_indicator_tensor[10000:])

batch_size = 10000

train_loader = DataLoader(
    train_data, batch_size= batch_size, shuffle=True)

val_loader = DataLoader(
    val_data, batch_size= batch_size, shuffle=True)

# %% [markdown]
# ### Define Likelihood with ACNET copula

# %%
from torch.autograd import Function, gradcheck
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pickle
import os
from main import sample

num_epochs = 500000

# %%
from dirac_phi import DiracPhi
from survival import SurvivalCopula
from survival import sample

import wandb

# start a new wandb run to track this script
run = wandb.init(
    # set the wandb project where this run will be logged
    project="ACNet Survival",
    # track hyperparameters and run metadata
    config={
    "dataset": "Clayton Copula Weibull Hazzards",
    "epochs": 50000,
    }
)


# Early stopping
best_val_loglikelihood = float('-inf')
epochs_no_improve = 0
early_stop_epochs = 1000

# Parameters for ACNet
depth = 2
widths = [10, 10]
lc_w_range = (0, 1.0)
shift_w_range = (0., 2.0)

phi = DiracPhi(depth, widths, lc_w_range, shift_w_range, device, tol = 1e-10).to(device)
model = SurvivalCopula(phi, device = device, num_features=10, tol=1e-10).to(device)
# optimizer = get_optim(optim_name, net, optim_args)

optimizer_event = optim.Adam([{"params": [model.scale_t], "lr": 0.01},
                            {"params": [model.shape_t], "lr": 0.01},
                            {"params": model.net_t.parameters(), "lr": 0.01},
                          ])
optimizer_censoring = optim.Adam([{"params": [model.scale_c], "lr": 0.01},
                            {"params": [model.shape_c], "lr": 0.01},
                            {"params": model.net_c.parameters(), "lr": 0.01},
                          ])
optimizer_copula = optim.Adam([
                            {"params": model.phi.parameters(), "lr": 0.01},
                          ])

train_loss_per_epoch = []
print("Start training!")
for epoch in range(num_epochs):
    loss_per_minibatch = []
    for i, (x , t, c) in enumerate(train_loader, 0):
        optimizer_copula.zero_grad()
        optimizer_event.zero_grad()
        optimizer_censoring.zero_grad()

        p = model(x, t, c, max_iter = 10000)
        logloss = -p
        logloss.backward() 
        scalar_loss = (logloss/p.numel()).detach().cpu().numpy().item()

        optimizer_censoring.step()
        optimizer_event.step()
        optimizer_copula.step()
        
        loss_per_minibatch.append(scalar_loss)
    train_loss_per_epoch.append(np.mean(loss_per_minibatch))
    if epoch % 100 == 0:
        print('Training loss at epoch %s: %.5f' %
                (epoch, train_loss_per_epoch[-1]))
        print(f"Shape Event: {model.shape_t.item(): .3f},\
            Shape Censoring: {model.shape_c.item(): .3f},\
            Scale Event: {model.scale_t.item(): .3f}, Scale Censoring: {model.scale_c.item(): .3f}")
    
        val_loglikelihoods = []
        for i, (x_val, t_val, c_val) in enumerate(val_loader, 0):
            p_val = model(x_val, t_val, c_val, max_iter = 10000)
            val_loglikelihood = p_val

        print('Validation log-likelihood at epoch %s: %s' % (epoch, val_loglikelihood.cpu().detach().numpy().item()))
    
        # Check if validation loglikelihood has improved
        if val_loglikelihood > best_val_loglikelihood:
            best_val_loglikelihood = val_loglikelihood
            epochs_no_improve = 0
            torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'loss': best_val_loglikelihood,
            }, 'checkpoint_gumbel_theta_6.pth')
        else:
            epochs_no_improve += 100

        # Early stopping condition
        if epochs_no_improve == early_stop_epochs:
            print('Early stopping triggered at epoch: %s' % epoch)
            break
    # Plot Samples from the learned copula
    if epoch % 1000 == 0:
        print('Scatter sampling')
        samples = sample(model, 2, 10000, device =  device)
        plt.scatter(samples[:, 0].cpu(), samples[:, 1].cpu())
        plt.savefig('./sample_figs/gumbel/epoch%s.png' %
                    (epoch))
        plt.clf()
    
    wandb.log({"log_likelihood": p, 
                "event_shape": model.shape_t.item(), "censoring_shape": model.shape_c.item(), \
                "event_scale": model.scale_t.item(), "censoring_scale": model.scale_c.item()})
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: weijia-zhang (causal-learning). Use `wandb login --relogin` to force relogin
# wandb version 0.15.3 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.2
# Run data is saved locally in <code>/home/weijia/code/SurvivalACNet/wandb/run-20230528_212848-rm4ns6oj</code>
# Syncing run <strong><a href='https://wandb.ai/causal-learning/ACNet%20Survival/runs/rm4ns6oj' target="_blank">toasty-sky-39</a></strong> to <a href='https://wandb.ai/causal-learning/ACNet%20Survival' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/causal-learning/ACNet%20Survival' target="_blank">https://wandb.ai/causal-learning/ACNet%20Survival</a>
#  View run at <a href='https://wandb.ai/causal-learning/ACNet%20Survival/runs/rm4ns6oj' target="_blank">https://wandb.ai/causal-learning/ACNet%20Survival/runs/rm4ns6oj</a>
# Start training!
# Training loss at epoch 0: 179457.75545
# Shape Event:  0.990,            Shape Censoring:  0.990,            Scale Event:  1.010, Scale Censoring:  1.010
# Validation log-likelihood at epoch 0: -141556.54786860477
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 100: 38110.07437
# Shape Event:  1.098,            Shape Censoring:  0.887,            Scale Event:  1.130, Scale Censoring:  1.148
# Validation log-likelihood at epoch 100: -38084.22211632924
# Training loss at epoch 200: 36041.14003
# Shape Event:  1.376,            Shape Censoring:  0.939,            Scale Event:  1.184, Scale Censoring:  1.161
# Validation log-likelihood at epoch 200: -36007.251427805124
# Training loss at epoch 300: 34243.03007
# Shape Event:  1.678,            Shape Censoring:  1.002,            Scale Event:  1.213, Scale Censoring:  1.177
# Validation log-likelihood at epoch 300: -34208.44925996645
# Training loss at epoch 400: 33012.58960
# Shape Event:  1.972,            Shape Censoring:  1.077,            Scale Event:  1.221, Scale Censoring:  1.190
# Validation log-likelihood at epoch 400: -33001.66399612587
# Training loss at epoch 500: 32156.10983
# Shape Event:  2.239,            Shape Censoring:  1.162,            Scale Event:  1.227, Scale Censoring:  1.197
# Validation log-likelihood at epoch 500: -32162.533166310648
# Training loss at epoch 600: 31545.10435
# Shape Event:  2.479,            Shape Censoring:  1.250,            Scale Event:  1.232, Scale Censoring:  1.199
# Validation log-likelihood at epoch 600: -31558.64436859185
# Training loss at epoch 700: 31091.28523
# Shape Event:  2.696,            Shape Censoring:  1.337,            Scale Event:  1.237, Scale Censoring:  1.201
# Validation log-likelihood at epoch 700: -31109.312133345982
# Training loss at epoch 800: 30752.06463
# Shape Event:  2.891,            Shape Censoring:  1.419,            Scale Event:  1.241, Scale Censoring:  1.202
# Validation log-likelihood at epoch 800: -30774.158548800035
# Training loss at epoch 900: 30498.15187
# Shape Event:  3.065,            Shape Censoring:  1.496,            Scale Event:  1.244, Scale Censoring:  1.203
# Validation log-likelihood at epoch 900: -30524.01118455669
# Training loss at epoch 1000: 30308.78078
# Shape Event:  3.220,            Shape Censoring:  1.569,            Scale Event:  1.248, Scale Censoring:  1.204
# Validation log-likelihood at epoch 1000: -30337.261450966187
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 1100: 30167.16390
# Shape Event:  3.358,            Shape Censoring:  1.637,            Scale Event:  1.251, Scale Censoring:  1.205
# Validation log-likelihood at epoch 1100: -30199.695361465376
# Training loss at epoch 1200: 30062.40092
# Shape Event:  3.480,            Shape Censoring:  1.701,            Scale Event:  1.254, Scale Censoring:  1.206
# Validation log-likelihood at epoch 1200: -30097.82414108565
# Training loss at epoch 1300: 29985.24011
# Shape Event:  3.586,            Shape Censoring:  1.760,            Scale Event:  1.256, Scale Censoring:  1.207
# Validation log-likelihood at epoch 1300: -30023.276840495935
# Training loss at epoch 1400: 29928.92336
# Shape Event:  3.678,            Shape Censoring:  1.814,            Scale Event:  1.259, Scale Censoring:  1.208
# Validation log-likelihood at epoch 1400: -29969.460321241095
# Training loss at epoch 1500: 29888.08674
# Shape Event:  3.758,            Shape Censoring:  1.864,            Scale Event:  1.261, Scale Censoring:  1.208
# Validation log-likelihood at epoch 1500: -29930.63357901341
# Training loss at epoch 1600: 29858.77016
# Shape Event:  3.826,            Shape Censoring:  1.910,            Scale Event:  1.263, Scale Censoring:  1.209
# Validation log-likelihood at epoch 1600: -29903.216030735093
# Training loss at epoch 1700: 29837.95759
# Shape Event:  3.884,            Shape Censoring:  1.951,            Scale Event:  1.265, Scale Censoring:  1.210
# Validation log-likelihood at epoch 1700: -29884.076290279758
# Training loss at epoch 1800: 29823.26938
# Shape Event:  3.932,            Shape Censoring:  1.989,            Scale Event:  1.266, Scale Censoring:  1.210
# Validation log-likelihood at epoch 1800: -29870.918671975593
# Training loss at epoch 1900: 29813.00696
# Shape Event:  3.972,            Shape Censoring:  2.023,            Scale Event:  1.268, Scale Censoring:  1.211
# Validation log-likelihood at epoch 1900: -29861.917803184115
# Training loss at epoch 2000: 29805.88839
# Shape Event:  4.004,            Shape Censoring:  2.053,            Scale Event:  1.269, Scale Censoring:  1.211
# Validation log-likelihood at epoch 2000: -29856.177999482665
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 2100: 29800.90841
# Shape Event:  4.031,            Shape Censoring:  2.080,            Scale Event:  1.270, Scale Censoring:  1.211
# Validation log-likelihood at epoch 2100: -29852.043250319846
# Training loss at epoch 2200: 29799.00574
# Shape Event:  4.052,            Shape Censoring:  2.104,            Scale Event:  1.271, Scale Censoring:  1.212
# Validation log-likelihood at epoch 2200: -29847.49271463161
# Training loss at epoch 2300: 29794.35385
# Shape Event:  4.069,            Shape Censoring:  2.126,            Scale Event:  1.272, Scale Censoring:  1.212
# Validation log-likelihood at epoch 2300: -29847.08121351592
# Training loss at epoch 2400: 29789.77528
# Shape Event:  4.083,            Shape Censoring:  2.145,            Scale Event:  1.273, Scale Censoring:  1.212
# Validation log-likelihood at epoch 2400: -29842.545296446027
# Training loss at epoch 2500: 29783.48735
# Shape Event:  4.097,            Shape Censoring:  2.167,            Scale Event:  1.273, Scale Censoring:  1.212
# Validation log-likelihood at epoch 2500: -29829.581926612824
# Training loss at epoch 2600: 29748.73979
# Shape Event:  4.117,            Shape Censoring:  2.207,            Scale Event:  1.275, Scale Censoring:  1.212
# Validation log-likelihood at epoch 2600: -29794.674133161203
# Training loss at epoch 2700: 29738.33220
# Shape Event:  4.138,            Shape Censoring:  2.258,            Scale Event:  1.277, Scale Censoring:  1.213
# Validation log-likelihood at epoch 2700: -29783.82460203045
# Training loss at epoch 2800: 29730.55918
# Shape Event:  4.156,            Shape Censoring:  2.307,            Scale Event:  1.278, Scale Censoring:  1.214
# Validation log-likelihood at epoch 2800: -29778.34009854409
# Training loss at epoch 2900: 29724.79586
# Shape Event:  4.169,            Shape Censoring:  2.352,            Scale Event:  1.280, Scale Censoring:  1.215
# Validation log-likelihood at epoch 2900: -29773.53565166469
# Training loss at epoch 3000: 29719.97328
# Shape Event:  4.179,            Shape Censoring:  2.394,            Scale Event:  1.280, Scale Censoring:  1.215
# Validation log-likelihood at epoch 3000: -29768.875711269196
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 3100: 29716.07161
# Shape Event:  4.185,            Shape Censoring:  2.432,            Scale Event:  1.282, Scale Censoring:  1.216
# Validation log-likelihood at epoch 3100: -29766.06334218083
# Training loss at epoch 3200: 29712.30794
# Shape Event:  4.189,            Shape Censoring:  2.467,            Scale Event:  1.283, Scale Censoring:  1.217
# Validation log-likelihood at epoch 3200: -29760.419834973804
# Training loss at epoch 3300: 29709.26642
# Shape Event:  4.191,            Shape Censoring:  2.500,            Scale Event:  1.284, Scale Censoring:  1.218
# Validation log-likelihood at epoch 3300: -29757.13357410206
# Training loss at epoch 3400: 29706.71664
# Shape Event:  4.193,            Shape Censoring:  2.531,            Scale Event:  1.284, Scale Censoring:  1.218
# Validation log-likelihood at epoch 3400: -29753.433137885804
# Training loss at epoch 3500: 29704.72710
# Shape Event:  4.193,            Shape Censoring:  2.559,            Scale Event:  1.287, Scale Censoring:  1.219
# Validation log-likelihood at epoch 3500: -29750.888309391426
# Training loss at epoch 3600: 29702.74501
# Shape Event:  4.193,            Shape Censoring:  2.586,            Scale Event:  1.287, Scale Censoring:  1.220
# Validation log-likelihood at epoch 3600: -29748.867005079126
# Training loss at epoch 3700: 29700.68748
# Shape Event:  4.190,            Shape Censoring:  2.613,            Scale Event:  1.289, Scale Censoring:  1.220
# Validation log-likelihood at epoch 3700: -29747.133608692755
# Training loss at epoch 3800: 29725.56083
# Shape Event:  4.183,            Shape Censoring:  2.641,            Scale Event:  1.289, Scale Censoring:  1.221
# Validation log-likelihood at epoch 3800: -29779.21732320355
# Training loss at epoch 3900: 29696.60954
# Shape Event:  4.177,            Shape Censoring:  2.668,            Scale Event:  1.291, Scale Censoring:  1.222
# Validation log-likelihood at epoch 3900: -29745.02210867247
# Training loss at epoch 4000: 29695.67463
# Shape Event:  4.170,            Shape Censoring:  2.695,            Scale Event:  1.291, Scale Censoring:  1.222
# Validation log-likelihood at epoch 4000: -29745.8505514407
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 4100: 29693.10675
# Shape Event:  4.164,            Shape Censoring:  2.720,            Scale Event:  1.292, Scale Censoring:  1.223
# Validation log-likelihood at epoch 4100: -29743.29983874844
# Training loss at epoch 4200: 29691.98631
# Shape Event:  4.159,            Shape Censoring:  2.743,            Scale Event:  1.294, Scale Censoring:  1.224
# Validation log-likelihood at epoch 4200: -29742.22057244604
# Training loss at epoch 4300: 29690.67646
# Shape Event:  4.154,            Shape Censoring:  2.767,            Scale Event:  1.295, Scale Censoring:  1.226
# Validation log-likelihood at epoch 4300: -29744.794322350557
# Training loss at epoch 4400: 29698.87138
# Shape Event:  4.151,            Shape Censoring:  2.788,            Scale Event:  1.295, Scale Censoring:  1.227
# Validation log-likelihood at epoch 4400: -29760.84590239198
# Training loss at epoch 4500: 29707.83096
# Shape Event:  4.148,            Shape Censoring:  2.808,            Scale Event:  1.296, Scale Censoring:  1.228
# Validation log-likelihood at epoch 4500: -29756.285234660223
# Training loss at epoch 4600: 29689.94953
# Shape Event:  4.145,            Shape Censoring:  2.825,            Scale Event:  1.298, Scale Censoring:  1.229
# Validation log-likelihood at epoch 4600: -29746.472253349326
# Training loss at epoch 4700: 29689.42564
# Shape Event:  4.143,            Shape Censoring:  2.841,            Scale Event:  1.300, Scale Censoring:  1.230
# Validation log-likelihood at epoch 4700: -29744.344500797626
# Training loss at epoch 4800: 29689.06266
# Shape Event:  4.142,            Shape Censoring:  2.855,            Scale Event:  1.301, Scale Censoring:  1.231
# Validation log-likelihood at epoch 4800: -29745.024942704524
# Training loss at epoch 4900: 29688.24619
# Shape Event:  4.140,            Shape Censoring:  2.867,            Scale Event:  1.303, Scale Censoring:  1.232
# Validation log-likelihood at epoch 4900: -29741.149674434506
# Training loss at epoch 5000: 29686.72315
# Shape Event:  4.139,            Shape Censoring:  2.877,            Scale Event:  1.304, Scale Censoring:  1.234
# Validation log-likelihood at epoch 5000: -29741.844787532827
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 5100: 29703.13156
# Shape Event:  4.138,            Shape Censoring:  2.887,            Scale Event:  1.306, Scale Censoring:  1.234
# Validation log-likelihood at epoch 5100: -29757.41646711275
# Training loss at epoch 5200: 29689.97737
# Shape Event:  4.138,            Shape Censoring:  2.894,            Scale Event:  1.307, Scale Censoring:  1.236
# Validation log-likelihood at epoch 5200: -29746.386590164177
# Training loss at epoch 5300: 29688.01540
# Shape Event:  4.137,            Shape Censoring:  2.900,            Scale Event:  1.309, Scale Censoring:  1.237
# Validation log-likelihood at epoch 5300: -29742.040358840874
# Training loss at epoch 5400: 29686.90900
# Shape Event:  4.136,            Shape Censoring:  2.905,            Scale Event:  1.310, Scale Censoring:  1.238
# Validation log-likelihood at epoch 5400: -29741.82723125146
# Training loss at epoch 5500: 29685.93537
# Shape Event:  4.136,            Shape Censoring:  2.909,            Scale Event:  1.312, Scale Censoring:  1.239
# Validation log-likelihood at epoch 5500: -29741.837059193545
# Training loss at epoch 5600: 29688.91223
# Shape Event:  4.136,            Shape Censoring:  2.913,            Scale Event:  1.313, Scale Censoring:  1.240
# Validation log-likelihood at epoch 5600: -29745.418442968647
# Training loss at epoch 5700: 29686.55575
# Shape Event:  4.135,            Shape Censoring:  2.916,            Scale Event:  1.315, Scale Censoring:  1.241
# Validation log-likelihood at epoch 5700: -29743.59514677711
# Training loss at epoch 5800: 29705.84203
# Shape Event:  4.134,            Shape Censoring:  2.919,            Scale Event:  1.316, Scale Censoring:  1.242
# Validation log-likelihood at epoch 5800: -29754.134996781566
# Training loss at epoch 5900: 29686.30457
# Shape Event:  4.135,            Shape Censoring:  2.920,            Scale Event:  1.318, Scale Censoring:  1.243
# Validation log-likelihood at epoch 5900: -29742.08770287142
# Training loss at epoch 6000: 29687.52615
# Shape Event:  4.134,            Shape Censoring:  2.922,            Scale Event:  1.319, Scale Censoring:  1.244
# Validation log-likelihood at epoch 6000: -29743.021425986342
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 6100: 29685.54914
# Shape Event:  4.134,            Shape Censoring:  2.923,            Scale Event:  1.320, Scale Censoring:  1.246
# Validation log-likelihood at epoch 6100: -29742.2859290559
# Training loss at epoch 6200: 29685.59672
# Shape Event:  4.134,            Shape Censoring:  2.924,            Scale Event:  1.322, Scale Censoring:  1.247
# Validation log-likelihood at epoch 6200: -29742.452087080994
# Training loss at epoch 6300: 29685.77623
# Shape Event:  4.134,            Shape Censoring:  2.925,            Scale Event:  1.323, Scale Censoring:  1.248
# Validation log-likelihood at epoch 6300: -29743.19659940617
# Training loss at epoch 6400: 29691.91245
# Shape Event:  4.134,            Shape Censoring:  2.927,            Scale Event:  1.325, Scale Censoring:  1.249
# Validation log-likelihood at epoch 6400: -29746.501232843842
# Training loss at epoch 6500: 29687.40216
# Shape Event:  4.134,            Shape Censoring:  2.927,            Scale Event:  1.327, Scale Censoring:  1.250
# Validation log-likelihood at epoch 6500: -29742.67126647898
# Training loss at epoch 6600: 29686.70461
# Shape Event:  4.134,            Shape Censoring:  2.927,            Scale Event:  1.328, Scale Censoring:  1.252
# Validation log-likelihood at epoch 6600: -29744.53370534554
# Training loss at epoch 6700: 29685.23800
# Shape Event:  4.134,            Shape Censoring:  2.927,            Scale Event:  1.330, Scale Censoring:  1.253
# Validation log-likelihood at epoch 6700: -29741.896354917943
# Training loss at epoch 6800: 29685.58013
# Shape Event:  4.134,            Shape Censoring:  2.928,            Scale Event:  1.331, Scale Censoring:  1.254
# Validation log-likelihood at epoch 6800: -29744.29351393722
# Training loss at epoch 6900: 29685.51520
# Shape Event:  4.133,            Shape Censoring:  2.929,            Scale Event:  1.332, Scale Censoring:  1.255
# Validation log-likelihood at epoch 6900: -29742.071060992348
# Training loss at epoch 7000: 29685.20046
# Shape Event:  4.134,            Shape Censoring:  2.929,            Scale Event:  1.334, Scale Censoring:  1.257
# Validation log-likelihood at epoch 7000: -29743.55864550877
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 7100: 29686.93463
# Shape Event:  4.134,            Shape Censoring:  2.929,            Scale Event:  1.335, Scale Censoring:  1.258
# Validation log-likelihood at epoch 7100: -29745.161781656363
# Training loss at epoch 7200: 29685.09640
# Shape Event:  4.133,            Shape Censoring:  2.930,            Scale Event:  1.337, Scale Censoring:  1.260
# Validation log-likelihood at epoch 7200: -29741.91086193045
# Training loss at epoch 7300: 29685.07221
# Shape Event:  4.133,            Shape Censoring:  2.930,            Scale Event:  1.338, Scale Censoring:  1.261
# Validation log-likelihood at epoch 7300: -29742.18015330044
# Training loss at epoch 7400: 29686.63742
# Shape Event:  4.132,            Shape Censoring:  2.931,            Scale Event:  1.340, Scale Censoring:  1.262
# Validation log-likelihood at epoch 7400: -29742.96174588683
# Training loss at epoch 7500: 29693.23343
# Shape Event:  4.133,            Shape Censoring:  2.932,            Scale Event:  1.341, Scale Censoring:  1.264
# Validation log-likelihood at epoch 7500: -29749.994318069057
# Training loss at epoch 7600: 29687.83774
# Shape Event:  4.133,            Shape Censoring:  2.932,            Scale Event:  1.342, Scale Censoring:  1.266
# Validation log-likelihood at epoch 7600: -29745.593856873867
# Training loss at epoch 7700: 29684.91762
# Shape Event:  4.132,            Shape Censoring:  2.932,            Scale Event:  1.344, Scale Censoring:  1.267
# Validation log-likelihood at epoch 7700: -29742.990808447055
# Training loss at epoch 7800: 29688.06530
# Shape Event:  4.132,            Shape Censoring:  2.933,            Scale Event:  1.345, Scale Censoring:  1.269
# Validation log-likelihood at epoch 7800: -29748.601541684387
# Training loss at epoch 7900: 29685.28185
# Shape Event:  4.132,            Shape Censoring:  2.933,            Scale Event:  1.347, Scale Censoring:  1.270
# Validation log-likelihood at epoch 7900: -29743.500892457527
# Training loss at epoch 8000: 29686.94579
# Shape Event:  4.132,            Shape Censoring:  2.934,            Scale Event:  1.348, Scale Censoring:  1.272
# Validation log-likelihood at epoch 8000: -29745.400206228776
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 8100: 29685.32882
# Shape Event:  4.131,            Shape Censoring:  2.934,            Scale Event:  1.350, Scale Censoring:  1.273
# Validation log-likelihood at epoch 8100: -29742.187608095257
# Training loss at epoch 8200: 29685.37367
# Shape Event:  4.131,            Shape Censoring:  2.935,            Scale Event:  1.351, Scale Censoring:  1.274
# Validation log-likelihood at epoch 8200: -29742.408642216215
# Training loss at epoch 8300: 29689.38448
# Shape Event:  4.131,            Shape Censoring:  2.935,            Scale Event:  1.353, Scale Censoring:  1.276
# Validation log-likelihood at epoch 8300: -29744.46591272644
# Training loss at epoch 8400: 29695.65564
# Shape Event:  4.131,            Shape Censoring:  2.936,            Scale Event:  1.353, Scale Censoring:  1.278
# Validation log-likelihood at epoch 8400: -29752.08630469976
# Training loss at epoch 8500: 29689.02416
# Shape Event:  4.130,            Shape Censoring:  2.937,            Scale Event:  1.355, Scale Censoring:  1.279
# Validation log-likelihood at epoch 8500: -29746.577167514835
# Training loss at epoch 8600: 29690.03352
# Shape Event:  4.130,            Shape Censoring:  2.937,            Scale Event:  1.357, Scale Censoring:  1.281
# Validation log-likelihood at epoch 8600: -29743.192686286868
# Training loss at epoch 8700: 29686.46095
# Shape Event:  4.130,            Shape Censoring:  2.937,            Scale Event:  1.358, Scale Censoring:  1.283
# Validation log-likelihood at epoch 8700: -29741.76739165064
# Training loss at epoch 8800: 29687.97554
# Shape Event:  4.130,            Shape Censoring:  2.938,            Scale Event:  1.359, Scale Censoring:  1.285
# Validation log-likelihood at epoch 8800: -29745.586417433442
# Training loss at epoch 8900: 29685.02312
# Shape Event:  4.129,            Shape Censoring:  2.938,            Scale Event:  1.361, Scale Censoring:  1.287
# Validation log-likelihood at epoch 8900: -29743.878241535287
# Training loss at epoch 9000: 29686.07282
# Shape Event:  4.128,            Shape Censoring:  2.940,            Scale Event:  1.362, Scale Censoring:  1.288
# Validation log-likelihood at epoch 9000: -29743.52684090291
# Scatter sampling
# Sampling from dim: 1
# Training loss at epoch 9100: 29686.79192
# Shape Event:  4.129,            Shape Censoring:  2.939,            Scale Event:  1.363, Scale Censoring:  1.291
# Validation log-likelihood at epoch 9100: -29764.786518368397
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 50
#      48 for epoch in range(num_epochs):
#      49     loss_per_minibatch = []
# ---> 50     for i, (x , t, c) in enumerate(train_loader, 0):
#      51         optimizer_copula.zero_grad()
#      52         optimizer_event.zero_grad()
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/utils/data/dataloader.py:634, in _BaseDataLoaderIter.__next__(self)
#     631 if self._sampler_iter is None:
#     632     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     633     self._reset()  # type: ignore[call-arg]
# --> 634 data = self._next_data()
#     635 self._num_yielded += 1
#     636 if self._dataset_kind == _DatasetKind.Iterable and \
#     637         self._IterableDataset_len_called is not None and \
#     638         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/utils/data/dataloader.py:678, in _SingleProcessDataLoaderIter._next_data(self)
#     676 def _next_data(self):
#     677     index = self._next_index()  # may raise StopIteration
# --> 678     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     679     if self._pin_memory:
#     680         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/utils/data/dataset.py:196, in TensorDataset.__getitem__(self, index)
#     195 def __getitem__(self, index):
# --> 196     return tuple(tensor[index] for tensor in self.tensors)
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/utils/data/dataset.py:196, in <genexpr>(.0)
#     195 def __getitem__(self, index):
# --> 196     return tuple(tensor[index] for tensor in self.tensors)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Plotting

# %%
# Scatter Plot
checkpoint = torch.load('checkpoint_gumbel_theta_6.pth')
model.load_state_dict(checkpoint['model_state_dict'])
samples =  sample(model, 2, 3000, device =  device)
plt.scatter(samples[:, 0].cpu(), samples[:, 1].cpu(), s = 15)
plt.savefig('./sample_figs/gumbel/best_epoch_gumbel.png')
plt.clf()

# plotting with known copula
known_copula = GumbelCopula(6, k_dim=2)
samples_known = known_copula.rvs(3000)
plt.scatter(samples_known[:, 0], samples_known[:, 1], s = 15)

plt.savefig('./sample_figs/gumbel/best_true_sample_gumbel.png')
plt.clf()

# %% [markdown]
# #### Joint Distribution (Cumulative Distribution Function) Spectral Plot

# %%
# learned model
n = 500
x1 = np.linspace(0.001, 1, n)
x2 = np.linspace(0.001, 1, n)
xv1, xv2 = np.meshgrid(x1, x2)
xv1_tensor = torch.tensor(xv1.flatten()).to(device)
xv2_tensor = torch.tensor(xv2.flatten()).to(device)
query = torch.stack((xv1_tensor, xv2_tensor)
                    ).double().t().requires_grad_(True)
cdf = model.cond_cdf(query, mode='cdf')
pdf = model.cond_cdf(query, mode='pdf')

heat_cdf = cdf.reshape(n,n).cpu().detach().numpy()
heat_pdf = pdf.reshape(n,n).cpu().detach().numpy()

# Create filled contour plot
plt.contourf(x1, x2, heat_cdf, 200, cmap='Spectral_r')
# Add a colorbar
# plt.colorbar(label='Cumulative Distribution Function')
# Show the plot
plt.savefig('Gumbel_Learned_CDF.png', dpi=300)

plt.clf()
# Create filled contour plot
plt.contourf(x1, x2, np.log(heat_pdf), 500, cmap='Spectral_r')
# Add a colorbar
# plt.colorbar(label='Log Density Function')
# Show the plot
plt.savefig('Gumbel_Learned_LogPDF.png', dpi=300)

# %%
# Known copula
from statsmodels.distributions.copula.api import (
    CopulaDistribution, GumbelCopula, FrankCopula, ClaytonCopula)

n = 1000
x1 = np.linspace(0.001, 1, n)
x2 = np.linspace(0.001, 1, n)
xv1, xv2 = np.meshgrid(x1, x2)
xv1_tensor = torch.tensor(xv1.flatten())
xv2_tensor = torch.tensor(xv2.flatten())
query = torch.stack((xv1_tensor, xv2_tensor)
                    ).t().numpy()
print(query.shape)

known_copula = GumbelCopula(6, k_dim=2)
heat_cdf = known_copula.cdf(u=query).reshape(n,n)
heat_pdf = known_copula.pdf(u=query).reshape(n,n)

# Create filled contour plot
plt.contourf(x1, x2, heat_cdf, 200, cmap='Spectral_r')
plt.tick_params(axis='both', direction='in', length=4, width=1)
# Add a colorbar
# plt.colorbar(label='Cumulative Distribution Function')
# Show the plot
# plt.show()
plt.savefig('Gumbel_Known_CDF.png', dpi=300)

plt.clf()
# Create filled contour plot
plt.contourf(x1, x2, np.log(heat_pdf), 200, cmap='Spectral_r')
plt.tick_params(axis='both', direction='in', length=4, width=1)
# Add a colorbar
# plt.colorbar(label='Log Density Function')
# Show the plot
# plt.show()
plt.savefig('Gumbel_Known_LogPDF.png', dpi=300)
